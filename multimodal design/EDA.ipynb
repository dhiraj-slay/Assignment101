# %%
import pandas as pd 
df = pd.read_csv('age_gender.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '#record', 'Age', 'Sex'], dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0     #record        Age
# count       48.00   48.000000  48.000000
# mean        23.50  166.229167  60.979167
# std         14.00   53.622494  21.750509
# min          0.00  100.000000  -1.000000
# 25%         11.75  112.750000  52.500000
# 50%         23.50  200.500000  65.500000
# 75%         35.25  215.500000  75.250000
# max         47.00  234.000000  89.000000

# %%
df.groupby('Sex').Age.plot(kind='kde')
# Out:
# Sex
# F    AxesSubplot(0.125,0.11;0.775x0.77)
# M    AxesSubplot(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
df.groupby('Sex').Age.hist()
# Out:
# Sex
# F    AxesSubplot(0.125,0.11;0.775x0.77)
# M    AxesSubplot(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object
